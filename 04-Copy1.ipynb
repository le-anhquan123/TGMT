# %%
# !pip install Pillow

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\admin\anaconda3\lib\site-packages (10.4.0)

# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/Admin/Documents/baitap TGMT/img/01/1.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=197x256>

# %%
# Định vị khu vực cắt:
region = (100,75,175,150)
#cắt vùng ảnh
cropped_image = img.crop(region)
display(cropped_image)
# Out:
# <PIL.Image.Image image mode=P size=75x75>

# %%
#dán 
#Xác định vị trí cần dán
paste_position = (150, 150)
img.paste(cropped_image, paste_position)
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=197x256>
