# %%
# !pip install Pillow

# %%
# !pip install Pillow

# %%
from PIL import Image
from imgtools import *
from IPython.display import display # to display images

# %%
my_dir = 'C:/Users/Admin/src/img/01'

# %%
imgs =  get_image_list(my_dir)

# %%
for img in imgs:
    print(img.size)
    display(img)
# Out:
# (197, 256)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=197x256>
# (230, 219)
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=230x219>
# (224, 225)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=224x225>
# (211, 239)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=211x239>
# (230, 220)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=230x220>
# (225, 224)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=225x224>
# (186, 270)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=186x270>
# (225, 225)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=225x225>
# (197, 256)
# <PIL.PngImagePlugin.PngImageFile image mode=P size=197x256>
