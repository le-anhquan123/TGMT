# %%
# !pip install Pillow

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\admin\anaconda3\lib\site-packages (10.4.0)

# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/Admin/Documents/baitap TGMT/img/01/1.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=197x256>

# %%
#xoay ảnh 
rotated_image = img.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=P size=197x256>

# %%
#xoay ảnh 
rotated_image = rotated_image.rotate(90)
display(rotated_image)
# Out:
# <PIL.Image.Image image mode=P size=197x256>

# %%
#transpose ảnh hoán đổi vị trí
transposed_image = img.transpose(Image.Transpose.ROTATE_90)
display(transposed_image)
# Out:
# <PIL.Image.Image image mode=P size=256x197>

# %%
#Chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=197x256>
