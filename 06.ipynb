# %%
# !pip install Pillow

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in c:\users\admin\anaconda3\lib\site-packages (10.4.0)

# %%
# Import lớp Image
from PIL import Image
from imgtools import *

# %%
my_path = 'C:/Users/Admin/Documents/baitap TGMT/img/01/1.png'

# %%
img = load_image(my_path)

# %%
display(img)
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=P size=197x256>

# %%
#Chuyển từ ảnh RGB sang ảnh xám
gray_image = img.convert("L")
display(gray_image)
# Out:
# <PIL.Image.Image image mode=L size=197x256>

# %%
red_band, green_band, blue_band = img.split()
red_band.show()
green_band.show()
blue_band.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[103], line 1
# ----> 1 red_band, green_band, blue_band = img.split()
#       2 red_band.show()
#       3 green_band.show()
#
# ValueError: not enough values to unpack (expected 3, got 1)

# %%
# Trộn ảnh
merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
display(merged_image)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[105], line 2
#       1 # Trộn ảnh
# ----> 2 merged_image =  Image.merge("RGB", (red_band, green_band, blue_band))
#       3 display(merged_image)
#
# NameError: name 'red_band' is not defined
